# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# %cd /content/drive/MyDrive/Colab/졸업작품/FOTS.PyTorch
# Out:
# /content/drive/MyDrive/Colab/졸업작품/FOTS.PyTorch

# %%
pwd
# Out:
# '/content/drive/MyDrive/Colab/졸업작품/FOTS.PyTorch'

# %%
# !git clone https://github.com/jiangxiluning/FOTS.PyTorch.git
# Out:
# Cloning into 'FOTS.PyTorch'...
# remote: Enumerating objects: 1880, done.
# remote: Counting objects: 100% (1130/1130), done.
# remote: Compressing objects: 100% (728/728), done.
# remote: Total 1880 (delta 503), reused 945 (delta 380), pack-reused 750
# Receiving objects: 100% (1880/1880), 7.64 MiB | 16.44 MiB/s, done.
# Resolving deltas: 100% (879/879), done.
# Updating files: 100% (627/627), done.

# %%
### testtesttest

# %%
# !python eval.py -c finetune.json -m pretrained_model/pretrain -i <icdar2015 folder contains train and test> --detection -o ./results --cuda --size "1280 720" --bs 2 --gpu 1
# Out:
# /bin/bash: line 1: icdar2015: No such file or directory

# %%
# !pip install loguru
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 1.8 MB/s eta 0:00:00
# ...

# %%
# !pip install pytorch_lightning
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 727.7/727.7 kB 6.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 764.8/764.8 kB 11.5 MB/s eta 0:00:00
# ...

# %%
# !pip install tensorboardX
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 3.3 MB/s eta 0:00:00
# ...

# %%
# !pip install einops
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 1.1 MB/s eta 0:00:00
# ...

# %%
# !pip install rorated_roi
# Out:
# ERROR: Could not find a version that satisfies the requirement rorated_roi (from versions: none)
# ERROR: No matching distribution found for rorated_roi

# %%
# !python FOTS/rroi_align/build.py develop
# Out:
# ['/content/drive/MyDrive/Colab/졸업작품/FOTS.PyTorch/FOTS/rroi_align/src/rroi_align_cuda.cpp', '/content/drive/MyDrive/Colab/졸업작품/FOTS.PyTorch/FOTS/rroi_align/src/rroi_align_kernel.cu']
# running develop
# /usr/local/lib/python3.10/dist-packages/setuptools/command/develop.py:40: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer, pypa/build or
#         other standards-based tools.
#
#         See https://github.com/pypa/setuptools/issues/917 for details.
#         ********************************************************************************
#
# !!
#   easy_install.initialize_options(self)
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
# ...

# %%
# !pip install wandb
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 10.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 189.5/189.5 kB 10.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.8/224.8 kB 10.8 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 6.8 MB/s eta 0:00:00
# ...
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8791 sha256=d4bd59e71597cfc3ef12df63d5528cf88dedbc8c60d5adcc4c1ac36d1c913de5
#   Stored in directory: /root/.cache/pip/wheels/e7/f3/22/152153d6eb222ee7a56ff8617d80ee5207207a8c00a7aab794
# Successfully built pathtools
# ...

# %%
# data_module.py에서 보니까 train, test 폴더 만들어야할듯?
# 데이터 저장 경로 다시 확인
# wandb visualize 아예 코드 지워버리고 문구 안뜨게

# %%
# !python train.py -c finetune.json

# %%
# invalid poly error?
# https://github.com/HaozhengLi/EAST_ICPR/issues/3
# 이미지가 너무 작아서 그럴수도 있는듯

# %%
# icdar dataset annotation form
# 789,415,816,417,817,472,790,471,BEAST
# 737,330,762,329,762,355,737,355,CITY
# 737,315,762,315,761,329,737,328,###
# 303,507,399,514,415,573,319,566,$20
# 765,338,791,338,792,354,765,354,###
# 764,308,791,309,792,335,764,334,LOST
# 406,650,455,652,452,663,403,662,FOOD
