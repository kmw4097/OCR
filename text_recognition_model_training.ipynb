# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# %cd /content/drive/MyDrive/Colab/졸업작품/deep-text-recognition-benchmark
# Out:
# /content/drive/MyDrive/Colab/졸업작품/deep-text-recognition-benchmark

# %%
# !pip install lmdb
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 299.2/299.2 kB 6.8 MB/s eta 0:00:00
# ...

# %%
# !pip install fire
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 kB 2.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for fire: filename=fire-0.5.0-py2.py3-none-any.whl size=116934 sha256=be81d58876cb724de9c0eb54fc0c2fe0acb38f76ce8b4062af5fc00947dececd
#   Stored in directory: /root/.cache/pip/wheels/90/d4/f7/9404e5db0116bd4d43e5666eaa3e70ab53723e1e3ea40c9a95
# Successfully built fire
# ...

# %% [markdown]
# # Load Dataset

# %% [markdown]
# # create gt txt file

# %% [markdown]
# # transform image(jpg, png), label(txt) to lmdb form dataset

# %%
# image(jpg, png), label(txt) -> lmdb form dataset으로 변형

# %%
# !python create_lmdb_dataset.py --inputPath data/training --gtFile data/training/train_gt.txt --outputPath data_lmdb/training
# Out:
# Created dataset with 5 samples

# %%
# !python create_lmdb_dataset.py --inputPath data/validation --gtFile data/validation/valid_gt.txt --outputPath data_lmdb/validation
# Out:
# Created dataset with 5 samples

# %% [markdown]
# # Training

# %%
# !python train.py \
--train_data data_lmdb/training --valid_data data_lmdb/validation \
--Transformation None --FeatureExtraction ResNet --SequenceModeling None --Prediction CTC \
--workers 2 --saved_model saved_models/None-ResNet-None-CTC.pth
# Out:
# Filtering the images containing characters which are not in opt.character
# Filtering the images whose label is longer than opt.batch_max_length
# --------------------------------------------------------------------------------
# dataset_root: data_lmdb/training
# opt.select_data: ['/']
# opt.batch_ratio: ['1']
# --------------------------------------------------------------------------------
# dataset_root:    data_lmdb/training	 dataset: /
# sub-directory:	/.	 num samples: 4
# num total samples of /: 4 x 1.0 (total_data_usage_ratio) = 4
# num samples of / per batch: 192 x 1.0 (batch_ratio) = 192
# --------------------------------------------------------------------------------
# Total_batch_size: 192 = 192
# --------------------------------------------------------------------------------
# dataset_root:    data_lmdb/validation	 dataset: /
# sub-directory:	/.	 num samples: 4
# --------------------------------------------------------------------------------
# ...
